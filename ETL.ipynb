# %% [markdown]
# # **Data Extraction**

# %% [markdown]
# ## Amazon Stock data collection from 2018 June until today(2023 June)

# %%
# Collecting stock data from different sources for traning our model
#Importing required libraries
import pandas_datareader as pdr

# %%
#Source-1 from tiingo
source1 = pdr.get_data_tiingo('AMZN', api_key="661114a49cd0ecde2c565ef415c31d41b2888ee4")
# Out:
# <ipython-input-226-24ce388242a6>:2: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   source1 = pdr.get_data_tiingo('AMZN', api_key="661114a49cd0ecde2c565ef415c31d41b2888ee4")

# %%
source1.head()
# Out:
#                                     close     high      low     open   volume  \
# symbol date
# AMZN   2018-06-21 00:00:00+00:00  1730.22  1763.10  1717.56  1760.00  4941148
#        2018-06-22 00:00:00+00:00  1715.67  1743.00  1711.90  1742.62  4075124
#        2018-06-25 00:00:00+00:00  1663.15  1705.00  1646.31  1702.51  7511196
#        2018-06-26 00:00:00+00:00  1691.09  1701.57  1663.34  1672.37  4386585
#        2018-06-27 00:00:00+00:00  1660.51  1711.95  1660.00  1708.11  4872201
#
#                                   adjClose  adjHigh   adjLow  adjOpen  \
# symbol date
# AMZN   2018-06-21 00:00:00+00:00   86.5110  88.1550  85.8780  88.0000
#        2018-06-22 00:00:00+00:00   85.7835  87.1500  85.5950  87.1310
#        2018-06-25 00:00:00+00:00   83.1575  85.2500  82.3155  85.1255
#        2018-06-26 00:00:00+00:00   84.5545  85.0785  83.1670  83.6185
#        2018-06-27 00:00:00+00:00   83.0255  85.5975  83.0000  85.4055
#
#                                   adjVolume  divCash  splitFactor
# symbol date
# AMZN   2018-06-21 00:00:00+00:00   98822960      0.0          1.0
#        2018-06-22 00:00:00+00:00   81502480      0.0          1.0
#        2018-06-25 00:00:00+00:00  150223920      0.0          1.0
#        2018-06-26 00:00:00+00:00   87731700      0.0          1.0
#        2018-06-27 00:00:00+00:00   97444020      0.0          1.0

# %%
source1.tail()
# Out:
#                                    close    high     low    open    volume  \
# symbol date
# AMZN   2023-06-13 00:00:00+00:00  126.66  128.41  125.18  128.12  50564785
#        2023-06-14 00:00:00+00:00  126.42  126.95  124.12  126.70  52422463
#        2023-06-15 00:00:00+00:00  127.11  127.69  124.32  125.21  60458471
#        2023-06-16 00:00:00+00:00  125.49  127.90  125.30  127.71  84247104
#        2023-06-20 00:00:00+00:00  125.78  127.25  124.50  124.97  55093683
#
#                                   adjClose  adjHigh  adjLow  adjOpen  \
# symbol date
# AMZN   2023-06-13 00:00:00+00:00    126.66   128.41  125.18   128.12
#        2023-06-14 00:00:00+00:00    126.42   126.95  124.12   126.70
#        2023-06-15 00:00:00+00:00    127.11   127.69  124.32   125.21
#        2023-06-16 00:00:00+00:00    125.49   127.90  125.30   127.71
#        2023-06-20 00:00:00+00:00    125.78   127.25  124.50   124.97
#
#                                   adjVolume  divCash  splitFactor
# symbol date
# AMZN   2023-06-13 00:00:00+00:00   50564785      0.0          1.0
#        2023-06-14 00:00:00+00:00   52422463      0.0          1.0
#        2023-06-15 00:00:00+00:00   60458471      0.0          1.0
#        2023-06-16 00:00:00+00:00   84247104      0.0          1.0
#        2023-06-20 00:00:00+00:00   55093683      0.0          1.0

# %%
# source-2 from stooq
# load necessary libraries
import pandas_datareader.data as web
source2 = web.DataReader('AMZN', 'stooq')

# %%
source2.head()
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2023-06-16  127.71  127.90  125.30  125.49  84247104
# 2023-06-15  125.21  127.69  124.32  127.11  60458471
# 2023-06-14  126.70  126.95  124.12  126.42  52422463
# 2023-06-13  128.12  128.41  125.18  126.66  50564785
# 2023-06-12  124.02  126.78  123.53  126.57  51473376

# %%
source2.tail()
# Out:
#                Open     High      Low    Close     Volume
# Date
# 2018-06-27  85.4055  85.5975  83.0000  83.0255   97444020
# 2018-06-26  83.6185  85.0785  83.1670  84.5545   87731700
# 2018-06-25  85.1255  85.2500  82.3155  83.1575  150223920
# 2018-06-22  87.1310  87.1500  85.5950  85.7835   81502480
# 2018-06-21  88.0000  88.1550  85.8780  86.5110   98822960

# %%
#Source-3 from yahoo finance
import pandas_datareader.data as web
import datetime as dt
import yfinance as yf

source3 = yf.download('GE', start='2018-06-01', end=dt.datetime.today())
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
source3.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2018-06-01  84.669426  84.969673  83.768692  84.669426  81.582436   9473692
# 2018-06-04  84.849579  85.329971  82.147362  82.327507  79.325890  13724786
# 2018-06-05  82.327507  83.648590  81.186569  82.867950  79.846642  11731772
# 2018-06-06  82.988052  83.408394  81.847115  81.907166  78.920868  10349057
# 2018-06-07  81.847115  82.867950  81.727013  82.747856  79.730919  11820699

# %%
source3.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-06-13  106.029999  107.150002  105.809998  106.739998  106.739998
# 2023-06-14  106.720001  106.800003  103.959999  104.699997  104.699997
# 2023-06-15  104.440002  105.639999  103.989998  105.410004  105.410004
# 2023-06-16  105.949997  108.900002  105.940002  106.290001  106.290001
# 2023-06-20  106.080002  106.169998  103.410004  104.019997  104.019997
#
#               Volume
# Date
# 2023-06-13   4318900
# 2023-06-14   5131100
# 2023-06-15   6969800
# 2023-06-16  10958600
# 2023-06-20   5359335

# %% [markdown]
# # **Feature Selection**

# %%
source1 = source1[['adjOpen','adjHigh','adjLow','adjClose']]
source1.head()
# Out:
#                                   adjOpen  adjHigh   adjLow  adjClose
# symbol date
# AMZN   2018-06-21 00:00:00+00:00  88.0000  88.1550  85.8780   86.5110
#        2018-06-22 00:00:00+00:00  87.1310  87.1500  85.5950   85.7835
#        2018-06-25 00:00:00+00:00  85.1255  85.2500  82.3155   83.1575
#        2018-06-26 00:00:00+00:00  83.6185  85.0785  83.1670   84.5545
#        2018-06-27 00:00:00+00:00  85.4055  85.5975  83.0000   83.0255

# %%
source2 = source2[['Open','High','Low','Close']]
source2.head()
# Out:
#               Open    High     Low   Close
# Date
# 2023-06-16  127.71  127.90  125.30  125.49
# 2023-06-15  125.21  127.69  124.32  127.11
# 2023-06-14  126.70  126.95  124.12  126.42
# 2023-06-13  128.12  128.41  125.18  126.66
# 2023-06-12  124.02  126.78  123.53  126.57

# %%
source3 = source3[['Open','High','Low','Close']]
source3.head()
# Out:
#                  Open       High        Low      Close
# Date
# 2018-06-01  84.669426  84.969673  83.768692  84.669426
# 2018-06-04  84.849579  85.329971  82.147362  82.327507
# 2018-06-05  82.327507  83.648590  81.186569  82.867950
# 2018-06-06  82.988052  83.408394  81.847115  81.907166
# 2018-06-07  81.847115  82.867950  81.727013  82.747856

# %% [markdown]
# # **DataFrame Formatting**

# %%
# Correctly formating the order of the source 2 (reversing the order)
import pandas as pd

source2_updated = source2.iloc[::-1]
source2_updated = source2_updated.reset_index(drop=True)
source2_updated.index = source2.index[::-1]
source2_updated.head()
# Out:
#                Open     High      Low    Close
# Date
# 2018-06-21  88.0000  88.1550  85.8780  86.5110
# 2018-06-22  87.1310  87.1500  85.5950  85.7835
# 2018-06-25  85.1255  85.2500  82.3155  83.1575
# 2018-06-26  83.6185  85.0785  83.1670  84.5545
# 2018-06-27  85.4055  85.5975  83.0000  83.0255

# %%
# Converting Source-1 index to proper format
source1.index = source1.index.get_level_values(1).date

source1.head()
# Out:
#             adjOpen  adjHigh   adjLow  adjClose
# 2018-06-21  88.0000  88.1550  85.8780   86.5110
# 2018-06-22  87.1310  87.1500  85.5950   85.7835
# 2018-06-25  85.1255  85.2500  82.3155   83.1575
# 2018-06-26  83.6185  85.0785  83.1670   84.5545
# 2018-06-27  85.4055  85.5975  83.0000   83.0255

# %%
# renaming columns properly
source1.columns = ['Open', 'High', 'Low', 'Close']
source1.head()
# Out:
#                Open     High      Low    Close
# 2018-06-21  88.0000  88.1550  85.8780  86.5110
# 2018-06-22  87.1310  87.1500  85.5950  85.7835
# 2018-06-25  85.1255  85.2500  82.3155  83.1575
# 2018-06-26  83.6185  85.0785  83.1670  84.5545
# 2018-06-27  85.4055  85.5975  83.0000  83.0255

# %%
# Checking all the source frames for proper format
print(source1.head())
print(source2_updated.head())
print(source3.head())
# Out:
#                Open     High      Low    Close
# 2018-06-21  88.0000  88.1550  85.8780  86.5110
# 2018-06-22  87.1310  87.1500  85.5950  85.7835
# 2018-06-25  85.1255  85.2500  82.3155  83.1575
# 2018-06-26  83.6185  85.0785  83.1670  84.5545
# 2018-06-27  85.4055  85.5975  83.0000  83.0255
#                Open     High      Low    Close
# Date
# 2018-06-21  88.0000  88.1550  85.8780  86.5110
# 2018-06-22  87.1310  87.1500  85.5950  85.7835
# 2018-06-25  85.1255  85.2500  82.3155  83.1575
# 2018-06-26  83.6185  85.0785  83.1670  84.5545
# 2018-06-27  85.4055  85.5975  83.0000  83.0255
#                  Open       High        Low      Close
# Date
# 2018-06-01  84.669426  84.969673  83.768692  84.669426
# 2018-06-04  84.849579  85.329971  82.147362  82.327507
# 2018-06-05  82.327507  83.648590  81.186569  82.867950
# 2018-06-06  82.988052  83.408394  81.847115  81.907166
# 2018-06-07  81.847115  82.867950  81.727013  82.747856

# %% [markdown]
# # **Data Merging**

# %%
# Merge all the frames and for duplicate data using average
data = pd.concat([source1, source2_updated, source3])
data.index = pd.to_datetime(data.index)
# Group by the index (assuming the index is the date)
data = data.groupby(data.index).mean()
data.head()
# Out:
#                  Open       High        Low      Close
# 2018-06-01  84.669426  84.969673  83.768692  84.669426
# 2018-06-04  84.849579  85.329971  82.147362  82.327507
# 2018-06-05  82.327507  83.648590  81.186569  82.867950
# 2018-06-06  82.988052  83.408394  81.847115  81.907166
# 2018-06-07  81.847115  82.867950  81.727013  82.747856

# %%
# Converting index to column
data.reset_index(inplace=True)

data.rename(columns={'index': 'Date'}, inplace=True)

# %%
data.head()
# Out:
#         Date       Open       High        Low      Close
# 0 2018-06-01  84.669426  84.969673  83.768692  84.669426
# 1 2018-06-04  84.849579  85.329971  82.147362  82.327507
# 2 2018-06-05  82.327507  83.648590  81.186569  82.867950
# 3 2018-06-06  82.988052  83.408394  81.847115  81.907166
# 4 2018-06-07  81.847115  82.867950  81.727013  82.747856

# %%
data['Date'] = data['Date'].astype(str)

# %%
import matplotlib.pyplot as plt

data[['Open','High','Low','Close']].plot()
plt.xlabel('Date')
plt.ylabel('Values')
plt.title('Visualizing prices')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # **Data Loading**

# %% [markdown]
# ## Using SQlite database

# %%
import sqlite3

# %%
conn = sqlite3.connect('stock_database.db')
c = conn.cursor()

# Create table
c.execute('''
    CREATE TABLE stock_data (
        id INTEGER PRIMARY KEY,
        Date TEXT,
        Open REAL,
        High REAL,
        Low REAL,
        Close REAL
    )
''')

# Commit the transaction
conn.commit()

# %%
#Inserting into database
# Iterate over DataFrame rows and insert each one into the SQLite table
for _, row in data.iterrows():
    c.execute('''
        INSERT INTO stock_data (Date, Open, High, Low, Close)
        VALUES (?, ?, ?, ?, ?)
    ''', (row['Date'], row['Open'], row['High'], row['Low'], row['Close']))

#commit the changes
conn.commit()

# %%
# Open a connection to the SQLite database
conn = sqlite3.connect('stock_database.db')
c = conn.cursor()

# Execute a query to fetch all records from the table
c.execute("SELECT * FROM stock_data Limit 5")

# Fetch all the rows
rows = c.fetchall()

# Iterate over the rows and print them
for row in rows:
    print(row)

# Close the connection
conn.close()
# Out:
# (1, '2018-06-01', 84.66942596435547, 84.96967315673828, 83.76869201660156, 84.66942596435547)
# (2, '2018-06-04', 84.84957885742188, 85.32997131347656, 82.1473617553711, 82.32750701904297)
# (3, '2018-06-05', 82.32750701904297, 83.64859008789062, 81.18656921386719, 82.86795043945312)
# (4, '2018-06-06', 82.98805236816406, 83.40839385986328, 81.84711456298828, 81.90716552734375)
# (5, '2018-06-07', 81.84711456298828, 82.86795043945312, 81.72701263427734, 82.74785614013672)
